# %% [markdown]
# # Import Data

# %%
from evpd3 import Solution
import pandas as pd
df = pd.read_csv('../Electric_Vehicle_Population_Data.csv')
obj=Solution(df)

# %%
obj.task2()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  153827.000000  153830.000000   153830.000000  153830.000000
# mean    98171.476704    2020.101391       65.723903    1273.032276
# std      2437.221384       3.019313       95.146279    9086.044139
# min      1730.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2018.000000        0.000000       0.000000
# 50%     98122.000000    2021.000000       17.000000       0.000000
# 75%     98370.000000    2023.000000       84.000000       0.000000
# max     99577.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         153491.000000    1.538300e+05       1.538270e+05
# mean              29.301594    2.124174e+08       5.297335e+10
# std               14.829077    8.054730e+07       1.620212e+09
# min                1.000000    4.385000e+03       1.081042e+09
# ...

# %%
from evpd4 import Solution_4
import pandas as pd
df = pd.read_csv('../Electric_Vehicle_Population_Data.csv')
obj=Solution_4(df)

# %% [markdown]
# #### Answering Question1: Were there more Tesla’s sold than any other kind of vehicle in Washington State?

# %%
obj.task1()
# Out:
# TESLA                   69581
# NISSAN                  13647
# CHEVROLET               12241
# FORD                     7816
# BMW                      6620
# KIA                      6534
# TOYOTA                   5386
# VOLKSWAGEN               4238
# VOLVO                    3666
# JEEP                     3468
# HYUNDAI                  3410
# AUDI                     3094
# RIVIAN                   2777
# CHRYSLER                 2755
# MERCEDES-BENZ            1108
# PORSCHE                  1041
# MITSUBISHI                884
# HONDA                     818
# MINI                      810
# FIAT                      797
# POLESTAR                  782
# SUBARU                    640
# SMART                     276
# LINCOLN                   231
# JAGUAR                    225
# MAZDA                     204
# LUCID                     191
# CADILLAC                  191
# LEXUS                     184
# GENESIS                   117
# LAND ROVER                 46
# ...

# %% [markdown]
# ### Answering Question2: How many vehicles were sold in each year? What was the trend in sales over time?

# %%
from evpd4 import Solution_4
import pandas as pd
df1 = pd.read_csv('../Electric_Vehicle_Population_Data.csv')
obj=Solution_4(df1)

# %%
obj.task2()
# Out:
# 2023    41157
# 2022    27396
# 2021    18566
# 2018    14231
# 2020    11194
# 2019    10601
# 2017     8487
# 2016     5598
# 2015     4893
# 2013     4539
# 2014     3568
# 2012     1649
# 2024     1103
# 2011      789
# 2010       24
# 2008       19
# 2000        8
# 1999        3
# 2002        2
# 1998        1
# 1997        1
# 2003        1
# Name: Model Year, dtype: int64

# %% [markdown]
# ### Answering Question 3:Which make is using which electric utility?

# %%
obj.task3()
# Out:
# Electric Utility                                    Electric Utility                                    Make
# AVISTA CORP                                         AVISTA CORP                                         TESLA         116
#                                                                                                         CHEVROLET      70
#                                                                                                         FORD           30
#                                                                                                         NISSAN         19
#                                                                                                         KIA            18
#                                                                                                                      ...
# PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM COUNTY  PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM COUNTY  FORD          184
# ...

# %% [markdown]
# # Part 5: Conclusion (10 Points)
# A brief, concise narrative explaining your conclusions.

# %% [markdown]
# # References (3 Points)
# Be sure to include proper citations for any references you may have relied on as part of your work.
# - https://catalog.data.gov/dataset/electric-vehicle-population-data
